# %%
#!/usr/bin/python

### for training set at the first 7 days ##########

'''
targets are
No. attribute description: index
1. click: 1
2. banner_pos: 4
3. site_category: 7
4. app_category: 10
5. device_model: 13
6. device_type: 14

Filter time range: hour : 2
training set:
14102100 - 14102500
validation set:
14102500 - 14102600
test set:
14102600 - 14102700
'''

input_file = "Data/train"
train_file = "Data/train_1234.txt"
test_file = "Data/validation_5.txt"
test_final_file = "Data/test_6.txt"
count = 0
train_count = 0
test_count = 0
test_final_count = 0

target_index = [1,4,7,10,13,14]

with open(input_file,'r') as infile:
    for line in infile:
        count += 1
        
        attributes = line.split(',')        
        hour = attributes[2]
        
        if hour < '14102500':
            with open(train_file,'a') as outfile:
                for i in range(len(target_index)):
                    if i != 0:
                        outfile.write(',' + attributes[target_index[i]])
                    else:
                        outfile.write(attributes[target_index[i]])

                outfile.write('\n')
                train_count += 1
                
        elif hour < '14102600' and hour >= '14102500':
            with open(test_file,'a') as outfile:
                for i in range(len(target_index)):
                    if i != 0:
                        outfile.write(',' + attributes[target_index[i]])
                    else:
                        outfile.write(attributes[target_index[i]])

                outfile.write('\n')
                test_count += 1
        
        elif hour < '14102700' and hour >= '14102600':
            with open(test_final_file,'a') as outfile:
                for i in range(len(target_index)):
                    if i != 0:
                        outfile.write(',' + attributes[target_index[i]])
                    else:
                        outfile.write(attributes[target_index[i]])

                outfile.write('\n')
                test_final_count += 1
            
print count,train_count,test_count,test_final_count


###################################################################
# Out:
# 40428968 16666175 3363122 3835892

# %%
#!/usr/bin/python

### for training set at the first 7 days ##########

'''
根据刚刚我做的统计结果，挑一下 我认为比较有用attribute出来：
标准1. 尽量值少
标准2. 尽量variance大
主要:
C1, banner_pos, app_domain, device_type, device_conn_type, C15, C16, C18, C19
感觉二者有关联:
site_category,app_category,
'''
'''
id,click,hour,C1,banner_pos,
site_id,site_domain,site_category,app_id,app_domain,
app_category,device_id,device_ip,device_model,device_type,
device_conn_type,C14,C15,C16,C17,
C18,C19,C20,C21
其中id, hour不要
'''

'''
target
1. click          1
2. banner_pos     4
3. site_category  7
4. app_domain     9
5. app_category   10
6. device_type    14
7. device_conn_type 15
8. C15            17
9. C16            18
10. C18            20
11. C19            21

Filter time range: hour : 2
training set:
14102100 - 14102500
validation set:
14102500 - 14102600
test set:
14102600 - 14102700
'''

input_file = "Data/train"
train_file = "Data/train_1234_new.txt"
test_file = "Data/validation_5_new.txt"
test_final_file = "Data/test_6_new.txt"
count = 0
train_count = 0
test_count = 0
test_final_count = 0

target_index = [1,4,7,9,10,14,15,17,18,20,21]

with open(input_file,'r') as infile:
    for line in infile:
        count += 1
        
        attributes = line.split(',')        
        hour = attributes[2]
        
        if hour < '14102500':
            with open(train_file,'a') as outfile:
                for i in range(len(target_index)):
                    if i != 0:
                        outfile.write(',' + attributes[target_index[i]])
                    else:
                        outfile.write(attributes[target_index[i]])

                outfile.write('\n')
                train_count += 1
                
        elif hour < '14102600' and hour >= '14102500':
            with open(test_file,'a') as outfile:
                for i in range(len(target_index)):
                    if i != 0:
                        outfile.write(',' + attributes[target_index[i]])
                    else:
                        outfile.write(attributes[target_index[i]])

                outfile.write('\n')
                test_count += 1
        
        elif hour < '14102700' and hour >= '14102600':
            with open(test_final_file,'a') as outfile:
                for i in range(len(target_index)):
                    if i != 0:
                        outfile.write(',' + attributes[target_index[i]])
                    else:
                        outfile.write(attributes[target_index[i]])

                outfile.write('\n')
                test_final_count += 1
            
print count,train_count,test_count,test_final_count


###################################################################

# %%
#get the submission data
input_file = "Data/test"
sub_file = "Data/sub_new.txt"
target_index = [1,4,7,9,10,14,15,17,18,20,21]
with open(input_file,'r') as infile:
    for line in infile:

        attributes = line.split(',')        
        
        with open(sub_file,'a') as outfile:
            for i in range(len(target_index)):
                if i != 0:
                    outfile.write(',' + attributes[target_index[i] - 1])
                else:
                    outfile.write(attributes[target_index[i] - 1])
            outfile.write('\n')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-6072021da2fc> in <module>()
#       6     for line in infile:
#       7
# ----> 8         attributes = line.split(',')
#       9
#      10         with open(sub_file,'a') as outfile:
#
# KeyboardInterrupt:
